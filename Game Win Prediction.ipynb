# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# First, we will call the data

# %%
df = pd.read_csv(r"C:\Users\Shubham\Desktop\Projects\Evaluation\baseball.csv")

# %% [markdown]
# # Data Understanding

# %%
df.head() #We will look into the top 5 rows of the data
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape #Here we check the shape of the data
# Out:
# (30, 17)

# %%
df.describe() #We do the statistical analysis of the data in the dataset
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# The data from above analysis seems good with only zero value to the 'CG' column which is a complete game with same pitcher and is possible so the data seems good.

# %%
df.columns #We look into the columns of the dataset
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# - W = Win: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs  to pitch at least 5 innings of work.
# - R = Runs scored: number of times a player crosses home plate.
# - AB = At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# - H = Hit: reaching base because of a batted, fair ball without error by the defense.
# - 2B = Double: hits on which the batter reaches second base safely without the contribution of a fielding error.
# - 3B = Triple: hits on which the batter reaches third base safely without the contribution of a fielding error.
# - HR = Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# - BB = Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first        base.
# - SO = Strikeout: number of batters who received strike three.
# - SB = Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense.
# - RA = Run average: number of runs allowed times nine divided by innings pitched.
# - ER = Earned run: number of runs that did not occur as a result of errors or passed balls.
# - ERA = Earned run average: total number of earned runs, multiplied by 9, divided by innings pitched.
# - CG = Complete game: number of games where player was the only pitcher for their team.
# - SHO = Shutout: number of complete games pitched with no runs allowed.
# - SV = Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher.
# - E = Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.isnull().sum() #Looking for null values in the dataset
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There are no null values present in the data. Let us look into the same using visualization

# %%
sns.heatmap(df.isnull(),annot=False) #Heat map presentation for null values
# Out:
# <AxesSubplot:>

# %% [markdown]
# Let us look into the correlation of the data to the target variable

# %%
df.corr() #Checking for correlation
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#Let us look into the correlation using visualization
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df.corr()['W'] #Correlation wrt to the target variable
# Out:
# W      1.000000
# R      0.430751
# AB    -0.087947
# H      0.037612
# 2B     0.427797
# 3B    -0.251118
# HR     0.307407
# BB     0.484342
# SO     0.111850
# SB    -0.157234
# RA    -0.812952
# ER    -0.809435
# ERA   -0.819600
# CG     0.080533
# SHO    0.471805
# SV     0.666530
# E     -0.089485
# Name: W, dtype: float64

# %% [markdown]
# We see that RA, ERA, ER has the highest negative correlation in order at a value in range 0.80-0.83, followed by SV, SHO, BB, 2B. The column with the least correlation is H.

# %% [markdown]
# Let us look into each of the column seperately

# %%
for i in df.columns:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# We see through the boxplot visualization for the columns the presence of outliers which is maximum in the column E

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.show()

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
train = df

# %%
train = np.sqrt(train)

# %%
train.skew()
# Out:
# W     -0.060392
# R      0.968676
# AB     0.172254
# H      0.649567
# 2B    -0.302835
# 3B    -0.142922
# HR     0.264948
# BB     0.053448
# SO    -0.348513
# SB     0.158381
# RA    -0.096160
# ER    -0.109548
# ERA   -0.133224
# CG    -0.311476
# SHO   -0.061761
# SV     0.410288
# E      0.763487
# dtype: float64

# %%
for i in train.columns:
    sns.distplot(train[i])
    plt.show()

# %% [markdown]
# # Scaling of Data

# %%
# Before scaling we split the data into feature and target variables
x = train.iloc[:,1:] #Feature variables
y = train.iloc[:,0] #Target Variables

# %%
#Scaling of data
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = sc.fit_transform(x)

# %%
x.shape
# Out:
# (30, 16)

# %% [markdown]
# # Best Random State

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
maxRS = 0
maxAcc = 0
for i in range(0,100):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc>maxAcc:
        maxAcc = acc
        maxRS = i
print("Max accuracy: \t", maxAcc)
print("Random State: \t", maxRS)
# Out:
# Max accuracy: 	 0.9233401529275442
# Random State: 	 90

# %% [markdown]
# # Model Training

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=90)

# %% [markdown]
# Linear Regression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
print("r2 score: \t", r2_score(y_test,pred)*100)
print("Mean Square Error : \t", mean_squared_error(y_test,pred))
print("Root Mean Square Error : \t", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2 score: 	 92.33401529275443
# Mean Square Error : 	 0.024588343535156137
# Root Mean Square Error : 	 0.15680670755792347

# %% [markdown]
# Ridge Regression

# %%
from sklearn.linear_model import Ridge

rr = Ridge()
rr.fit(x_train,y_train)
pred = rr.predict(x_test)
print("r2 score: \t", r2_score(y_test,pred)*100)
print("Mean Square Error : \t", mean_squared_error(y_test,pred))
print("Root Mean Square Error : \t", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2 score: 	 82.5232137932597
# Mean Square Error : 	 0.0560561023211604
# Root Mean Square Error : 	 0.23676169943882477

# %% [markdown]
# KNN MODEL

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor()
knn.fit(x_train,y_train)
pred = knn.predict(x_test)
print("r2 score: \t", r2_score(y_test,pred)*100)
print("Mean Square Error : \t", mean_squared_error(y_test,pred))
print("Root Mean Square Error : \t", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2 score: 	 49.60771722345769
# Mean Square Error : 	 0.16163125909437862
# Root Mean Square Error : 	 0.40203390291663044

# %% [markdown]
# SUPPORT VECTOR REGRESSION

# %%
from sklearn.svm import SVR

svr = SVR()
svr.fit(x_train,y_train)
pred = svr.predict(x_test)
print("r2 score: \t", r2_score(y_test,pred)*100)
print("Mean Square Error : \t", mean_squared_error(y_test,pred))
print("Root Mean Square Error : \t", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2 score: 	 66.32119830355731
# Mean Square Error : 	 0.10802342785550301
# Root Mean Square Error : 	 0.3286691769173115

# %% [markdown]
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(x_train,y_train)
pred = rf.predict(x_test)
print("r2 score: \t", r2_score(y_test,pred)*100)
print("Mean Square Error : \t", mean_squared_error(y_test,pred))
print("Root Mean Square Error : \t", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2 score: 	 73.64555740415891
# Mean Square Error : 	 0.08453083497696234
# Root Mean Square Error : 	 0.29074187001008706

# %% [markdown]
# Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
pred = dt.predict(x_test)
print("r2 score: \t", r2_score(y_test,pred)*100)
print("Mean Square Error : \t", mean_squared_error(y_test,pred))
print("Root Mean Square Error : \t", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2 score: 	 20.76568362187684
# Mean Square Error : 	 0.254140944089954
# Root Mean Square Error : 	 0.5041239372316634

# %% [markdown]
# Out of all the models Linear Regression and the Ridge Regression has the highest r2_score

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
scr1 = cross_val_score(lr, x, y, cv=5, scoring='r2')
print("Cross validation score of Linear Regression is: \t", scr1.mean())
# Out:
# Cross validation score of Linear Regression is: 	 -0.08294630872929072

# %%
scr2 = cross_val_score(rr, x, y, cv=5, scoring='r2')
print("Cross validation score of Ridge Regression is: \t", scr2.mean())
# Out:
# Cross validation score of Ridge Regression is: 	 0.4202769323683147

# %%
scr3 = cross_val_score(dt, x, y, cv=5)
print("Cross validation score of Decision Tree Regressor is: \t", scr3.mean())
# Out:
# Cross validation score of Decision Tree Regressor is: 	 -2.1385557722745974

# %%
scr4 = cross_val_score(rf, x, y, cv=5)
print("Cross validation score of Random Forest Regressor is: \t", scr4.mean())
# Out:
# Cross validation score of Random Forest Regressor is: 	 -0.4946394410235264

# %%
scr5 = cross_val_score(knn, x, y, cv=5)
print("Cross validation score of KNeighbour Regressor is: \t", scr5.mean())
# Out:
# Cross validation score of KNeighbour Regressor is: 	 -0.20042984486764093

# %%
scr6 = cross_val_score(svr, x, y, cv=5)
print("Cross validation score of SVR is: \t", scr6.mean())
# Out:
# Cross validation score of SVM is: 	 -0.18508695892314275

# %% [markdown]
# We have the highest cross validation score for Ridge Regression.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'alpha': (1.0,2.0,3.0),
              'copy_X': (True, False),
              'fit_intercept': (True, False),
              'max_iter': (range(1,5)),
              'normalize': (False, True),
              'random_state': (None,range(1,5)),
              'solver': ('auto', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'lbfgs'),
              'tol': (0.001,0.002,0.003)}

# %%
GridSearchCV.get_params(rr)
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': None,
#  'normalize': False,
#  'random_state': None,
#  'solver': 'auto',
#  'tol': 0.001}

# %%
gcv = GridSearchCV(rr, parameters, cv=5, scoring='r2')

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': (1.0, 2.0, 3.0), 'copy_X': (True, False),
#                          'fit_intercept': (True, False),
#                          'max_iter': range(1, 5), 'normalize': (False, True),
#                          'random_state': (None, range(1, 5)),
#                          'solver': ('auto', 'cholesky', 'lsqr', 'sparse_cg',
#                                     'sag', 'lbfgs'),
#                          'tol': (0.001, 0.002, 0.003)},
#              scoring='r2')

# %%
gcv.best_score_
# Out:
# 0.7116361043252606

# %% [markdown]
# Let us put this value into the Ridge Regression model and check the efficiency if increased

# %%
RR = Ridge(**gcv.best_params_)

# %%
RR.fit(x_train,y_train)
# Out:
# Ridge(alpha=3.0, copy_X=False, max_iter=4, solver='sag')

# %%
pred = RR.predict(x_test)
r2_score(y_test,pred)
# Out:
# 0.8310799019534589

# %% [markdown]
# We note the efficiency has increased from 82% to 83%. The model has been sucesfully tuned.

# %% [markdown]
# # Saving the best model

# %%
import joblib
joblib.dump(RR,"baseball.pkl")
# Out:
# ['baseball.pkl']
