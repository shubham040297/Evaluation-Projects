# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
#importing the dataset
df = pd.read_csv(r'C:\Users\Shubham\Desktop\Projects\FlipRobo\Customer Retention\Customer_retention_dataset\customer UC.csv')

# %%
#Calling the dataset to see the features
pd.set_option('display.max_columns',None) #to show all columns
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
#looking at the shape of the data
df.shape
# Out:
# (269, 71)

# %% [markdown]
# There are 269 rows and 71 columns

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# We see that there are no null values present in the data

# %% [markdown]
# Let us first create a data visualization for each column separately to understand the data

# %%
pn = 1

for column in df:
    if pn<=71:
        plt.figure(figsize=(50,50))
        plt.subplot(3,24,pn)
        sns.countplot(df[column])
        #plt.xlabel(column)
        plt.xticks(rotation=90)
        plt.show()
    pn+=1

# %% [markdown]
# Few details that we can make out through the visualization of the data are:
# - Female does more shopping through online retailers compared to men.
# - Most application users are from metro city such as Delhi, Noida, Banglore
# - Most of the purchases that happen online are from people who spend more time on the application (more than 6 min on average)
# - Various other factors that influence are the monetory savings, more detail of the products and the retailers
# - Whereas comparitively less influence is by the webpage visualization and ease of use of the application
# - Finally, targeted advertisement requirement as most people use the search engine to get the required destination
#
# Therefore, technically there are two factors that influence the customer retention:
# - Hedonic Value
# - Utilitarian Value

# %% [markdown]
# ## Classification wrt Gender

# %%
i=1
for column in df:
    if i==1:
        i+=1
    else:
        print(df.pivot_table(values=column, columns='1Gender of respondent', aggfunc=(lambda x: x.mode()[0])), '\n')
# Out:
# 1Gender of respondent       Female         Male
# 2 How old are you?     21-30 years  31-40 years
#
# 1Gender of respondent                         Female   Male
# 3 Which city do you shop online from?  Greater Noida  Delhi
#
# 1Gender of respondent                               Female    Male
# 4 What is the Pin Code of where you shop online...  201308  110044
#
# 1Gender of respondent                              Female       Male
# 5 Since How Long You are Shopping Online ?  Above 4 years  3-4 years
#
# 1Gender of respondent                                           Female  \
# 6 How many times you have made an online purcha...  Less than 10 times
#
# 1Gender of respondent                                             Male
# 6 How many times you have made an online purcha...  Less than 10 times
#
# 1Gender of respondent                                        Female  \
# 7 How do you access the internet while shopping...  Mobile internet
#
# ...

# %% [markdown]
# ## Hedonic Value

# %% [markdown]
# Hedonic value consists of gratification, role, deals, social and adventure in the usage of the application.
# Let us classify these factors among the gender column to get more specified data

# %%
#'Gratification' influence wrt gender
df.pivot_table(values='31 Enjoyment is derived from shopping online', columns='1Gender of respondent', aggfunc=(lambda x: x.mode()[0]))
# Out:
# 1Gender of respondent                                     Female  \
# 31 Enjoyment is derived from shopping online  Strongly agree (5)
#
# 1Gender of respondent                                    Male
# 31 Enjoyment is derived from shopping online  indifferent (3)

# %%
#'Role' influence wrt gender
df.pivot_table(values='32 Shopping online is convenient and flexible', columns='1Gender of respondent', aggfunc=(lambda x: x.mode()[0]))
# Out:
# 1Gender of respondent                                      Female  \
# 32 Shopping online is convenient and flexible  Strongly agree (5)
#
# 1Gender of respondent                                        Male
# 32 Shopping online is convenient and flexible  Strongly agree (5)

# %%
#'Social' influence wrt gender
df.pivot_table(values='44 Shopping on your preferred e-tailer enhances your social status', columns='1Gender of respondent', aggfunc=(lambda x: x.mode()[0]))
# Out:
# 1Gender of respondent                                        Female  \
# 44 Shopping on your preferred e-tailer enhances...  indifferent (3)
#
# 1Gender of respondent                                          Male
# 44 Shopping on your preferred e-tailer enhances...  indifferent (3)

# %%
#'Adventure' influence wrt gender
df.pivot_table(values='43 Shopping on the website gives you the sense of adventure', columns='1Gender of respondent', aggfunc=(lambda x: x.mode()[0]))
# Out:
# 1Gender of respondent                                  Female       Male
# 43 Shopping on the website gives you the sense ...  Agree (4)  Agree (4)

# %% [markdown]
# ## Utilitarian value

# %% [markdown]
# Utilitarian value consists of product offerings, convenience, product information and Monetory Savings while using the application. Let us classify these factors among the gender column to get more specified data

# %%
#'product offerings' influence wrt gender
df.pivot_table(values='39 Offering a wide variety of listed product in several category', columns='1Gender of respondent', aggfunc=(lambda x: x.mode()[0]))
# Out:
# 1Gender of respondent                                           Female  \
# 39 Offering a wide variety of listed product in...  Strongly agree (5)
#
# 1Gender of respondent                                    Male
# 39 Offering a wide variety of listed product in...  Agree (4)

# %%
#'convenience' influence wrt gender
df.pivot_table(values='32 Shopping online is convenient and flexible', columns='1Gender of respondent', aggfunc=(lambda x: x.mode()[0]))
# Out:
# 1Gender of respondent                                      Female  \
# 32 Shopping online is convenient and flexible  Strongly agree (5)
#
# 1Gender of respondent                                        Male
# 32 Shopping online is convenient and flexible  Strongly agree (5)

# %%
#'product informations' influence wrt gender
df.pivot_table(values='40 Provision of complete and relevant product information', columns='1Gender of respondent', aggfunc=(lambda x: x.mode()[0]))
# Out:
# 1Gender of respondent                                           Female  \
# 40 Provision of complete and relevant product i...  Strongly agree (5)
#
# 1Gender of respondent                                    Male
# 40 Provision of complete and relevant product i...  Agree (4)

# %%
#'Monetory Savings' influence wrt gender
df.pivot_table(values='41 Monetary savings', columns='1Gender of respondent', aggfunc=(lambda x: x.mode()[0]))
# Out:
# 1Gender of respondent              Female                Male
# 41 Monetary savings    Strongly agree (5)  Strongly agree (5)

# %% [markdown]
# ## General Analysis Conclusion

# %% [markdown]
# From the above data we can see that it is mostly Females who are affected by the hedonic and the utilitarian values whereas the Men are more encouraged by the convinience of the online shopping and time and monetary management.

# %% [markdown]
# This concludes that curated offers are more required towards female customers, in addition to the more product options relevant to the product in search and best deals. Most of the users going offine in the middle of the search process is in search for a better deal for the product.
